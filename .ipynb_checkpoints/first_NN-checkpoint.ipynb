# %% [markdown]
# # Tutorial taken from
# https://www.tensorflow.org/tutorials/keras/basic_classification

# %%
#import packages
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
#import dataset
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
plt.imshow(train_images[9], cmap=mpl.cm.cool)
plt.colorbar()
plt.grid(False)
plt.show()

# %%
train_images = train_images/255
test_images = test_images/255

# %%
#plot a bunch of the images
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=mpl.cm.cool)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(150, activation=tf.nn.relu),
    keras.layers.Dense(100, activation=tf.nn.relu),
    keras.layers.Dense(50, activation =tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %%
model.compile(optimizer='adam',
             loss = 'sparse_categorical_crossentropy',
             metrics=['accuracy']) #for classification problems

# %%
model.fit(train_images, train_labels, epochs=20)
# Out:
# Train on 60000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.1349 - accuracy: 0.9482
# Epoch 2/20
# 60000/60000 [==============================] - 4s 74us/sample - loss: 0.1340 - accuracy: 0.9480
# Epoch 3/20
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.1342 - accuracy: 0.9488
# Epoch 4/20
# 60000/60000 [==============================] - 4s 68us/sample - loss: 0.1284 - accuracy: 0.9509
# Epoch 5/20
# 60000/60000 [==============================] - 4s 66us/sample - loss: 0.1288 - accuracy: 0.9510
# Epoch 6/20
# 60000/60000 [==============================] - 4s 66us/sample - loss: 0.1246 - accuracy: 0.9525
# Epoch 7/20
# 60000/60000 [==============================] - 4s 66us/sample - loss: 0.1208 - accuracy: 0.9545
# Epoch 8/20
# 60000/60000 [==============================] - 4s 66us/sample - loss: 0.1193 - accuracy: 0.9538
# Epoch 9/20
# 60000/60000 [==============================] - 4s 66us/sample - loss: 0.1177 - accuracy: 0.9537
# Epoch 10/20
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.1174 - accuracy: 0.9555
# Epoch 11/20
# 34080/60000 [================>.............] - ETA: 1s - loss: 0.1197 - accuracy: 0.9559

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)

print(test_acc)

# %%
#make predictions
predictions = model.predict(test_images)

# %%
predictions[0]
# Out:
# array([9.2463797e-06, 6.2437530e-06, 4.2356028e-06, 9.9739218e-06,
#        1.5806605e-05, 2.0487675e-02, 2.3220093e-05, 1.7447047e-02,
#        2.3840212e-05, 9.6197271e-01], dtype=float32)

# %%
np.argmax(predictions[0])
# Out:
# 9

# %%
def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array[i], true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    
    plt.imshow(img, cmap=mpl.cm.pink)
    
    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'green'
    else:
        color = 'red'
        
    plt.xlabel('{} {:2.0f}% ({})'.format(class_names[predicted_label],
                                         100*np.max(predictions_array),
                                         class_names[true_label]),
                                         color = color)

# %%
def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array[i], true_label[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    thisplot = plt.barh(range(10), predictions_array, color='#777777')
    plt.xlim([0,1])
    predicted_label = np.argmax(predictions_array)
    
    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('green')

# %%
i = 9
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plot_image(i, predictions, test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions, test_labels)
plt.yticks(range(10), class_names)
plt.show()

# %%
# Plot the first X test images, their predicted label, and the true label
# Color correct predictions in blue, incorrect predictions in red
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions, test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions, test_labels)
plt.show()
